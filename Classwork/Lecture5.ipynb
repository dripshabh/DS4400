# %%
import numpy as np
from numpy import ones
from numpy import array
import matplotlib.pyplot as plt
from numpy import mean

# %%
x_samples = np.array([[1, 2, 2, 3]]).T
y_samples = np.array([[1, 1, 2, 2]]).T
# Out:
# array([[1],
#        [2],
#        [2],
#        [3]])

# %%
#Linear regression assumption
feature_map = np.array([[1, 1],
                     [2,1],
                     [2,1],
                     [3,1]])

print(feature_map)
# Out:
# [[1 1]
#  [2 1]
#  [2 1]
#  [3 1]]

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-11-7fcc07d18597> in <cell line: 0>()
#       3 def f_prime(w):
#       4     return (2/4)*(np.dot(feature_map.T,w) - y_samples).dot(x_samples)
# ----> 5 f_prime(np.array([[0.5,0.5]]).T)
#
# <ipython-input-11-7fcc07d18597> in f_prime(w)
#       2     return (1/4)*(np.dot(feature_map.T, w) - y_samples)**2
#       3 def f_prime(w):
# ----> 4     return (2/4)*(np.dot(feature_map.T,w) - y_samples).dot(x_samples)
#       5 f_prime(np.array([[0.5,0.5]]).T)
#
# ValueError: shapes (2,4) and (2,1) not aligned: 4 (dim 1) != 2 (dim 0)

# %%
!#/usr/bin/env python
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # Q1

# %%
def solve(A,y,question):
  e = Exception
  try:
    result = np.linalg.solve(A,y)
  except Exception as e:
    print ("error", e)
    result = "that it doesn't have a unique solution."
  print ("the answer to question", question, "is", result)
# A10 = np.array([[1,0,3,0],
#                [2,1,1,1],
#                [2,4,1,0],
#                [0,0,1,1]])
# y10 = np.array([[1],
#                [3],
#                [2],
#                [1]])

A11 = np.array([[0,1,5],
              [1,4,3],
              [2,7,1]])
y11 = np.array([[-4],
              [-2],
              [-2]])

A12 = np.array([[2,0,-6],
              [0,1,2],
              [3,6,-2]])
y12 = np.array([[-8],
              [3],
              [-4]])

A13 = np.array([[1,1,1],
              [4,4,4],
              [3,-1,2]])
y13 = np.array([[3],
              [7],
              [5]])
#solve(A10,y10,"example")
solve(A11,y11,"1-1")
solve(A12,y12,"1-2")
solve(A13,y13,"1-3")
# Out:
# error Singular matrix
# the answer to question 1-1 is that it doesn't have a unique solution.
# the answer to question 1-2 is [[ 2.]
#  [-1.]
#  [ 2.]]
# error Singular matrix
# the answer to question 1-3 is that it doesn't have a unique solution.

# %% [markdown]
# #Q2

# %%
A21 = np.array([[1,-1,1,-1, 1],
               [2,-1,3, 0,4],
               [3,-2,2,1,1],
               [1, 0,1,2,1],
                [0,0,0,0,0]])
y21 = np.array([[1],
               [2],
               [2],
               [7],
                [0]])
A22 = np.array([[3,2],
              [6, 4]])
y22 = np.array([[7],
              [-3]])
A23 = np.array([[3,2,-1],
              [2, -2,3],
                [1,3,-2]])
y23 = np.array([[7],
              [-1],
              [4]])
solve(A21,y21,"2-1")
solve(A22,y22,"2-2")
solve(A23,y23,"2-3")
# Out:
# error Singular matrix
# the answer to question 2-1 is that it doesn't have a unique solution.
# error Singular matrix
# the answer to question 2-2 is that it doesn't have a unique solution.
# the answer to question 2-3 is [[ 2.22222222]
#  [-1.11111111]
#  [-2.55555556]]

# %% [markdown]
# #Q3

# %%
A31 = np.array([[1,0],
               [0,1]])
y31 = np.array([[3],
               [6]])
A32 = np.array([[1,-2],
              [0, 0]])
y32 = np.array([[134],
              [0]])
A33 = np.array([[5,3,10],
              [0, 0, 0],
                [0,0,0]])
y33 = np.array([[2],
              [1],
              [0]])
solve(A31,y31,"3-1")
solve(A32,y32,"3-2")
solve(A33,y33,"3-3")
# Out:
# the answer to question 3-1 is [[3.]
#  [6.]]
# error Singular matrix
# the answer to question 3-2 is that it doesn't have a unique solution.
# error Singular matrix
# the answer to question 3-3 is that it doesn't have a unique solution.

# %% [markdown]
# #Q4

# %%
A41 = np.array([[1/4,0,1,5],
               [2,1,0, 0],
               [-1, 0,1,2],
                [0,0,0,0]])
y41 = np.array([[2],
               [20],
               [-2],
                [0]])
solve(A41,y41,"4-1")
# Out:
# error Singular matrix
# the answer to question 4-1 is that it doesn't have a unique solution.
